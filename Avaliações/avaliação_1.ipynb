# %% [markdown]
# # Avaliação 1- Probabilidade e estatística

# %% [markdown]
# ### Nome do aluno: Nara Miranda Guimarães

# %% [markdown]
# ### Instruções:
# Escreva seu nome na célula acima. Esta avaliação é composta de 14 questões. <br>As questões discursivas devem ser respondidas na célula logo abaixo do enunciado, após a marcação "Resposta:".
# <br >As questões que envolvem código devem ser feitas ou completadas apenas dentro da área definida pelas marcações:
# <br>"### COMEÇO DO CÓDIGO ###"
# <br>"### FIM DO CÓDIGO ###"<br>
# Dentro desse espaço, o aluno deve escrever linhas de código e trocar os três pontos (...) por linhas de código pertinentes.
# Nada precisa ser alterado ou feito no código fora dessas marcações.

# %% [markdown]
# #### Questão 1: Qual a probabilidade de se obter um número par em um lançamento de dados de 6 lados? Justifique

# %% [markdown]
# Resposta:
#
# p = evento / espaço amostral
#
# evento = 2,4,6
#
# espaço amostral = 1,2,3,4,5,6
#
# p = 3/6 = 1/2 = 0.5 = 50%
#
#
# A probabilidade é definida como as chances de ocorrência de uma evento dadas todas a todas as possibilidades existentes (evento / espaçõ amostral). O espaço amostral nesse caso seriam 6 números possíveis e o evento seria apenas 3, resultando em uma probabilidade de 0.5 ou 50%.

# %%
import math

lados= [1,2,3,4,5,6]

evento = 0

for lado in lados:
    
    if (lado % 2 == 0):
        evento += 1
        
prob = evento / len(lados)

print("A proabilidade final é de ", prob)
# Out:
# A proabilidade final é de  0.5

# %% [markdown]
# #### Questão 2: O código abaixo simula o lançamento de um dado 10000 vezes. Os resultados dos lançamentos são armazenados em uma lista 'lancamentos'. Um trecho de código é criado em seguida para iterar entre os valores. Complete o código dentro da área delimitada, fazendo a verificação de quais números são pares, fazendo a contagem de pares e armazenando o valor na variável 'conta_pares'. Calcule a proporção de números pares em relação ao total de lançamentos feitos. O resultado é próximo ao obtido na questão 1?

# %%
import random

lancamentos = []
conta_pares = 0
proporcao = 0

for i in range(10000):
    lancamentos.append(random.randint(1,6))
    
for lancamento in lancamentos:
    ### COMEÇO DO CÓDIGO ### 
    if lancamento % 2 == 0:
        conta_pares += 1
    proporcao = conta_pares / len(lancamentos)
    ### FIM DO CÓDIGO ###
print('A proporçao é igual a ', proporcao)

####### COMENTAR A PERGUNTAR
# Out:
# A proporçao é igual a  0.4969

# %% [markdown]
# Quanto mais jogos, maior a probabilidade da proporção resultar em 0.5

# %% [markdown]
# #### Questão 3: Complete o código abaixo, que calcula e imprime o número de permutações (a ordem importa!) possíveis com as letras A,B,C,D.

# %%
import math

### COMEÇO DO CÓDIGO ### 
x = 4
permutacoes = math.factorial(x)
### FIM DO CÓDIGO ###
print('O número de permutações possíveis é: ', permutacoes)
# Out:
# O número de permutações possíveis é:  24

# %%
from itertools import permutations 
array_op = 'ABCD'
totals = list(permutations(array_op))
print('O número de permutações possíveis é: ', len(totals))  
for total in list(totals):
    print(total)
# Out:
# O número de permutações possíveis é:  24
# ('A', 'B', 'C', 'D')
# ('A', 'B', 'D', 'C')
# ('A', 'C', 'B', 'D')
# ('A', 'C', 'D', 'B')
# ('A', 'D', 'B', 'C')
# ('A', 'D', 'C', 'B')
# ('B', 'A', 'C', 'D')
# ('B', 'A', 'D', 'C')
# ('B', 'C', 'A', 'D')
# ('B', 'C', 'D', 'A')
# ('B', 'D', 'A', 'C')
# ('B', 'D', 'C', 'A')
# ('C', 'A', 'B', 'D')
# ('C', 'A', 'D', 'B')
# ('C', 'B', 'A', 'D')
# ('C', 'B', 'D', 'A')
# ('C', 'D', 'A', 'B')
# ('C', 'D', 'B', 'A')
# ('D', 'A', 'B', 'C')
# ('D', 'A', 'C', 'B')
# ('D', 'B', 'A', 'C')
# ('D', 'B', 'C', 'A')
# ('D', 'C', 'A', 'B')
# ('D', 'C', 'B', 'A')

# %% [markdown]
# #### Questão 4: Complete o código abaixo, que calcula e imprime o número de combinações de duas letras (a ordem não importa!) possíveis com as letras A,B,C,D.

# %%
import math

### COMEÇO DO CÓDIGO ### 
n = 4
r = 2
combinacoes = math.factorial(n)/(math.factorial(n-r)*math.factorial(r))
### FIM DO CÓDIGO ###
print('O número de permutações possíveis é: ', combinacoes)
# Out:
# O número de permutações possíveis é:  6.0

# %%
from itertools import combinations 
array_op = ('A','B','C','D')
total_combinacoes = list(combinations(array_op, 2))
print(total_combinacoes)
print('O número de permutações possíveis é: ', len(total_combinacoes))
# Out:
# [('A', 'B'), ('A', 'C'), ('A', 'D'), ('B', 'C'), ('B', 'D'), ('C', 'D')]
# O número de permutações possíveis é:  6

# %% [markdown]
# #### Questão 5: Considere o diagrama de Venn na imagem abaixo. Escreva quais são os conjuntos A, B, Intersecção de A e B e União de A e B.
# ![image.png](attachment:image.png)

# %% [markdown]
# Resposta:
#
# A = {0,1,2,3,4,5,6,7}
#
# B = {0,2,4,6,8}
#
# A U B = {0,1,2,3,4,5,6,7,8}
#
# A intersec B = {0,2,4,6}

# %% [markdown]
# #### Questão 6: Considere os eventos:
# #### a: preço da ação da Petrobrás diminui <br> b: notícia negativa da Petrobrás é veiculada
# #### Como você descreveria  de forma mais "didática" a probabilidade condicional P(a|b)?

# %% [markdown]
# Resposta:
#
# A probabilidade condicional é dada quando um evento, no caso a redução no valor das ações da Petrobrás, estão associadas a um outro evento que aconteceu previamente, que nesse caso seria a veiculação de uma notícia negativa da empresa. Sendo assim, consegue-se quantificar o quanto um evento tem efeito sobre o outro. Em termos matemáticos, seria a probabilidade da intersecção desses dois eventos pela probabilidade do evento b.
#
# P(a|b) = P(a intersec b)/P(b)

# %% [markdown]
# #### Questão 7: Complete o código abaixo para calcular a probabilidade binomial de se lançar um dado 20 vezes, e obter o resultado 5 em um total de 3 lançamentos.

# %%
from scipy.stats import binom

X = 3
n = 20
p = 1/6
### COMEÇO DO CÓDIGO ### 
probabilidade = binom.pmf(X, n, p)
### FIM DO CÓDIGO ###
print('A probabilidade é de:',probabilidade)
# Out:
# A probabilidade é de: 0.23788656613784978

# %% [markdown]
# #### Questão 8: Considere o seguinte problema: "Um porto recebe, em média, 10 barcos entre 16h00 e 17h00 nas sextas feiras. Qual é a probabilidade de que apenas 4 barcos cheguem nesta sexta feira, entre 16h00 e 17h00?". Que tipo de distribuição de probabilidade deve ser usada nessa situação? Que características do problema nos levam a essa conclusão? (Não é necessário resolver o problema).

# %% [markdown]
# resposta:
#
# Todas as vezes em que a unidade de tempo da análise for a mesma (que no caso considera o período das 16 às 17 horas), assumindo que o evento modelado é independente, devemos utilizar a distrubição de Poison, pois a mesma trata do número de sucesso por unidade de tempo possibilidando com que a probabilidade de um cenário seja calculado com base em um outro já conhecido.

# %% [markdown]
# #### Questão 9: Cite a principal característica que diferencia a distribuição Normal das distribuições Binomial e de Poisson. Qual é o valor da área abaixo da curva de uma distribuição normal?

# %% [markdown]
# resposta:
#
# Enquanto a distribuição binomial pode ser usada para encontrar a probabilidade de um número designado de sucessos em n tentativas, a distribuição de Poisson é usada para encontrar a probabilidade de um número designado de sucessos por unidade de intervalo (Tempo, Comprimento, etc). Ambas são distribições discretas.
#
#
#
# O valor da área abaixo da curva de uma distribuição normal é igual a 1.
#
#
# A distribuição normal conhecida também como distribuição gaussiana é a mais importante distribuição contínua. Sua importância se deve a vários fatores, dentre eles pode-se citar o teorema central do limite. A distribuição normal é simétrica em torno da média o que implica que e média, a mediana e a moda são todas coincidentes.
#
# A distribuição normal aproxima muito bem as probabilidades de uma variável aleatória binomial a medida em que n aumenta.
#
# Distribuiçõs de probabilidade discreta é quando a soma de todas as probabilidades individuais é igual a 1. Enquanto que na distribuição contínua, a área do gráfico é igual a 1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Referência: http://www.inf.ufsc.br/~marcelo.menezes.reis/Aula04CPGCC.pdf

# %% [markdown]
# #### Questão 10: Um estudo foi realizado sobre a durabilidade dos drones usados para análise de áreas de desmatamento, visto que 70% deles eram perdidos na mata. Os cientistas mediam o desgaste das peças dos drones que retornavam para tirar conclusões. Que tipo de viés pode estar sendo cometido neste estudo?

# %% [markdown]
# Resposta:
#
# Neste caso, está sendo cometido o viés de sobrevivência, uma vez que só é feita a análise nos drone sobreviventes sem levar em contar aqueles que não retornaram. Em outras palavras, escolhem-se os membros que sobreviveram a algum processo e ignoram-se os que foram eliminados.

# %% [markdown]
# #### Questão 11: Qual é o enunciado do Teorema do Limite Central? Qual a diferença entre média populacional e média da amostra?

# %% [markdown]
# Resposta:
#
# O teorema do limite central diz que a média dos valores de um grupo de amostras será normalmente distribuída em torno da média da população. E quanto maior o tamanho da amostra, mais normal será a distribuição.
# O teorema do limite central é um resultado fundamental em aplicações práticas e teóricas, pois ele garante que mesmo que os dados não sejam distribuídos segundo uma normal a média dos dados converge para uma distribuição normal conforme o número de dados aumenta.
#
# A média amostral é a média calculada a partir de um grupo de variáveis ​​aleatórias, retiradas da população. Pode ser considerado um estimador eficiente e imparcial da média populacional, o que significa que o valor mais esperado para a estatística da amostra é a estatística da população, independentemente do erro amostral.
#
# A média populacional é definida como a média de todos os elementos da população. É um meio de característica de grupo, em que grupo se refere a elementos da população como itens, pessoas, etc. e a característica é o item de interesse. Como a população é muito grande e desconhecida, a média populacional é uma constante desconhecida.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Referência: https://pt.gadget-info.com/difference-between-sample-mean

# %% [markdown]
# #### Considere o seguinte problema para as questões 12, 13 e 14: <br> <br> Uma empresa contratou um novo servidor para armazenar seu website, visto que ele custa menos pelo serviço. O desempenho do novo servidor deve ser idêntico ao anterior. As páginas demoravam, em média, 3.125 segundos para carregar antes da troca, com desvio padrão de 0.700 segundos. O cientista de dados da empresa foi responsabilizado por determinar se as páginas continuam carregando no mesmo tempo que antes (nem mais, nem menos). A diretoria espera um nível de confiança de 99% (nível de significância de 1 %). Uma amostragem foi realizada com 40 acessos à página, com uma média amostral de 2.875 segundos. A hipotése nula H0 foi pré-definida como: "o tempo de carregamento das páginas continua sendo igual a 3.125 segundos."

# %% [markdown]
# #### Questão 12: Escreva um trecho de código para calcular o z-score da média amostral:

# %%
import math   

### COMEÇO DO CÓDIGO ### 
z_score = (2.875 - 3.125)/(0.700/math.sqrt(40))
### FIM DO CÓDIGO ###
print('O z-score da média amostral é de: ', z_score)
# Out:
# O z-score da média amostral é de:  -2.2587697572631282

# %% [markdown]
# #### Questão 13: Escreva um trecho de código para calcular os valores críticos:

# %%
from scipy import stats

### COMEÇO DO CÓDIGO ### 
valor_critico_1 = stats.norm.ppf(0.01/2)
valor_critico_2 = stats.norm.ppf(1 - (0.01/2))
### FIM DO CÓDIGO ###
print('Os valores críticos são: ', valor_critico_1, valor_critico_2)
# Out:
# Os valores críticos são:  -2.575829303548901 2.5758293035489004

# %%
if (valor_critico_1 <z_score and valor_critico_2>z_score):
    print('Não rejeita H0')
else:
    print('Rejeita H0')
# Out:
# Não rejeita H0

# %%
valor_critico_1 < z_score < valor_critico_2
# Out:
# True

# %% [markdown]
# #### Questão 14: Baseado nos resultados das questôes 12 e 13, podemos afirmar (com 99 % de nível de confiança) que os tempos do teste estão estatisticamente iguais aos anteriores? Por que?resposta

# %% [markdown]
# Resposta: Sim podemos, a hipótese H0 não é rejeitada porque o valor de z_score se encontra entre os valores críticos calculados para um nível de 99% de confiança. Como pode ser visualizado pela trecho de código acima, que faz essa comparação entre os valores de z_score, valores críticos 1 e 2, e  a conclusão final é de não rejeitar H0.
# Estatisticamente e com nível de confiança de 99%, pode-se dizer que o tempo de carregamento das páginas continua sendo igual a 3.125 segundos, com isso, não existem evidências suficientes para rejeitar a afirmação de H0.
